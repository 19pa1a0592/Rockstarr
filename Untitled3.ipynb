# %% [markdown]
# <a href="https://colab.research.google.com/github/19pa1a0592/Rockstarr/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p='hello world '
print(p)
# Out:
# hello world
